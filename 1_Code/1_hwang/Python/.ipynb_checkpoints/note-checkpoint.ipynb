# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic'   # '맑은 고딕'으로 설정 
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv("X_test.csv", encoding = 'cp949')
dft = pd.read_csv("X_train.csv", encoding = 'cp949')
df = pd.concat([dft, df], ignore_index=True)

# %%
df = pd.read_csv("X_test.csv", encoding = 'cp949')

# %%
df
# Out:
#         custid         date_time store        product     brand   corner  \
# 0        30000  2000-05-17 19:00    본점  4405230126000        루츠     진케주얼
# 1        30000  2000-08-03 15:20    본점  4208200014400    제임스딘.P       내의
# 2        30000  2000-08-03 15:40    본점  4405600026000       퀵실버     진케주얼
# 3        30000  2000-08-06 16:20    본점  4405600026000       퀵실버     진케주얼
# 4        30000  2000-08-06 16:20    본점  4405600026000       퀵실버     진케주얼
# ...        ...               ...   ...            ...       ...      ...
# 689772   49993  2001-01-31 17:50   신촌점  4405551020474       톰키드       아동
# 689773   49993  2001-01-31 18:33   신촌점  2139140008300     폴로화장품       향수
# 689774   49994  2001-04-14 17:50    본점  4230120011274      스테파넬     영트랜드
# 689775   49994  2001-04-14 18:10    본점  4409271026010  써스데이아일앤드     진케주얼
# 689776   49994  2001-04-15 16:02   무역점  2116052008000      크리니크  수입종합화장품
#
#            pc       part  imported  amount  discount  installment
# 0        진케주얼  케주얼,구두,아동         0   47000      2350            1
# 1       내의란제리  케주얼,구두,아동         0   17500       880            1
# 2        진케주얼  케주얼,구두,아동         0  158000      7900            1
# 3        진케주얼  케주얼,구두,아동         0 -158000     -7900            1
# 4        진케주얼  케주얼,구두,아동         0  148000      7400            1
# ...       ...        ...       ...     ...       ...          ...
# 689772     아동       아동문화         0   20000         0            1
# 689773    화장품       패션잡화         0   70000      3500            1
# 689774   영트렌디  케주얼,구두,아동         0   39000         0            1
# 689775   진케주얼  케주얼,구두,아동         0   34200         0            1
# 689776    화장품       명품잡화         1   86000      8600            1
#
# [689777 rows x 12 columns]

# %%
df1 = df[['store','amount']]

# %%
df1.groupby('store').sum()
# Out:
#             amount
# store
# 무역점    20303958035
# 본점     23321349884
# 신촌점    13338232796
# 천호점    11320509128

# %%
df2 = df['brand']
df2 = df2.drop_duplicates()
df2 = df2.reset_index(drop=True)
df2
# Out:
# 0        에스티로더
# 1          시슬리
# 2         크리니크
# 3           듀퐁
# 4           랑콤
#          ...
# 1901       라씰로
# 1902      씽크핑크
# 1903       엘피노
# 1904    세화종합상행
# 1905      케릭터인
# Name: brand, Length: 1906, dtype: object

# %%
df3 = df[['custid','amount']]
df3.groupby('custid').sum()
# Out:
#          amount
# custid
# 30000   2078240
# 30001   4158320
# 30002   8007256
# 30003   1367820
# 30004   2890471
# ...         ...
# 49990    213000
# 49991    770080
# 49992    221000
# 49993    143029
# 49994    159200
#
# [19995 rows x 1 columns]

# %%
df4 = df['custid']
df4 = df4.drop_duplicates()
df4 = df4.reset_index(drop=True)
df4
# Out:
# 0        30000
# 1        30001
# 2        30002
# 3        30003
# 4        30004
#          ...
# 19990    49990
# 19991    49991
# 19992    49992
# 19993    49993
# 19994    49994
# Name: custid, Length: 19995, dtype: int64

# %%
dft = pd.read_csv("X_train.csv", encoding = 'cp949')

# %%
dft
# Out:
#          custid         date_time store        product  brand   corner  \
# 0             0  2000-06-25 12:12   무역점  2116050008000  에스티로더  수입종합화장품
# 1             0  2000-06-25 12:42   무역점  4125440008000    시슬리  수입종합화장품
# 2             0  2000-08-26 18:10    본점  2116052008000   크리니크  수입종합화장품
# 3             0  2000-08-26 18:30    본점  4106430119900     듀퐁     수입의류
# 4             0  2000-09-03 18:02   무역점  2139141008000     랑콤  수입종합화장품
# ...         ...               ...   ...            ...    ...      ...
# 1036648   29998  2001-01-21 13:20   무역점  4241080013074    바닐라     영캐주얼
# 1036649   29998  2001-04-07 16:33   무역점  2139141008000     랑콤  수입종합화장품
# 1036650   29999  2001-03-21 18:03   천호점  4109290004000  루이까또즈      핸드백
# 1036651   29999  2001-03-29 18:23   천호점  4139350206500  소피에르핀      넥타이
# 1036652   29999  2001-04-21 13:13   천호점  4104840008000     샤넬  수입종합화장품
#
#               pc   part  imported  amount  discount  installment
# 0            화장품   명품잡화         1   90000      9000            3
# 1            화장품   명품잡화         1   39000      3900            1
# 2            화장품   잡화파트         1  175000     17500            3
# 3           명품토탈   잡화파트         1  455000     45500            3
# 4            화장품   명품잡화         0  100000     10000            3
# ...          ...    ...       ...     ...       ...          ...
# 1036648  트랜디 케쥬얼  여성캐주얼         0  120000         0            3
# 1036649      화장품   명품잡화         0   38000      1900            1
# 1036650      핸드백     잡화         0   46000      2300            1
# 1036651       셔츠   남성의류         0   49000      2450            1
# 1036652      화장품     잡화         1   52000      2600            1
#
# [1036653 rows x 12 columns]

# %%
df = pd.concat([dft, df], ignore_index=True)

# %%
df
# Out:
#          custid         date_time store        product     brand   corner  \
# 0             0  2000-06-25 12:12   무역점  2116050008000     에스티로더  수입종합화장품
# 1             0  2000-06-25 12:42   무역점  4125440008000       시슬리  수입종합화장품
# 2             0  2000-08-26 18:10    본점  2116052008000      크리니크  수입종합화장품
# 3             0  2000-08-26 18:30    본점  4106430119900        듀퐁     수입의류
# 4             0  2000-09-03 18:02   무역점  2139141008000        랑콤  수입종합화장품
# ...         ...               ...   ...            ...       ...      ...
# 1726425   49993  2001-01-31 17:50   신촌점  4405551020474       톰키드       아동
# 1726426   49993  2001-01-31 18:33   신촌점  2139140008300     폴로화장품       향수
# 1726427   49994  2001-04-14 17:50    본점  4230120011274      스테파넬     영트랜드
# 1726428   49994  2001-04-14 18:10    본점  4409271026010  써스데이아일앤드     진케주얼
# 1726429   49994  2001-04-15 16:02   무역점  2116052008000      크리니크  수입종합화장품
#
#            pc       part  imported  amount  discount  installment
# 0         화장품       명품잡화         1   90000      9000            3
# 1         화장품       명품잡화         1   39000      3900            1
# 2         화장품       잡화파트         1  175000     17500            3
# 3        명품토탈       잡화파트         1  455000     45500            3
# 4         화장품       명품잡화         0  100000     10000            3
# ...       ...        ...       ...     ...       ...          ...
# 1726425    아동       아동문화         0   20000         0            1
# 1726426   화장품       패션잡화         0   70000      3500            1
# 1726427  영트렌디  케주얼,구두,아동         0   39000         0            1
# 1726428  진케주얼  케주얼,구두,아동         0   34200         0            1
# 1726429   화장품       명품잡화         1   86000      8600            1
#
# [1726430 rows x 12 columns]

# %%
df1 = df[['custid','amount']]
df1.groupby('custid').sum()
# Out:
#          amount
# custid
# 0       1742000
# 1       2772100
# 2       3750850
# 3       2300500
# 4       1045000
# ...         ...
# 49990    213000
# 49991    770080
# 49992    221000
# 49993    143029
# 49994    159200
#
# [49995 rows x 1 columns]

# %%
df3 = df[['custid', 'date_time', 'store']]

# %%
df3
# Out:
#          custid         date_time store
# 0             0  2000-06-25 12:12   무역점
# 1             0  2000-06-25 12:42   무역점
# 2             0  2000-08-26 18:10    본점
# 3             0  2000-08-26 18:30    본점
# 4             0  2000-09-03 18:02   무역점
# ...         ...               ...   ...
# 1726425   49993  2001-01-31 17:50   신촌점
# 1726426   49993  2001-01-31 18:33   신촌점
# 1726427   49994  2001-04-14 17:50    본점
# 1726428   49994  2001-04-14 18:10    본점
# 1726429   49994  2001-04-15 16:02   무역점
#
# [1726430 rows x 3 columns]

# %%
data = []
for i, j in zip(df3['date_time'], range(len(df3))):
    data.append(i[:10])

# %%
#df3['date'] = data
data = pd.Series(data)
data
# Out:
# 0          2000-06-25
# 1          2000-06-25
# 2          2000-08-26
# 3          2000-08-26
# 4          2000-09-03
#               ...
# 1726425    2001-01-31
# 1726426    2001-01-31
# 1726427    2001-04-14
# 1726428    2001-04-14
# 1726429    2001-04-15
# Length: 1726430, dtype: object

# %%
df3['date'] = data
df3
# Out:
# <ipython-input-37-89e79955b16e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['date'] = data
#          custid         date_time store        date
# 0             0  2000-06-25 12:12   무역점  2000-06-25
# 1             0  2000-06-25 12:42   무역점  2000-06-25
# 2             0  2000-08-26 18:10    본점  2000-08-26
# 3             0  2000-08-26 18:30    본점  2000-08-26
# 4             0  2000-09-03 18:02   무역점  2000-09-03
# ...         ...               ...   ...         ...
# 1726425   49993  2001-01-31 17:50   신촌점  2001-01-31
# 1726426   49993  2001-01-31 18:33   신촌점  2001-01-31
# 1726427   49994  2001-04-14 17:50    본점  2001-04-14
# 1726428   49994  2001-04-14 18:10    본점  2001-04-14
# 1726429   49994  2001-04-15 16:02   무역점  2001-04-15
#
# [1726430 rows x 4 columns]

# %%
df3 = df3.drop(['date_time'], axis=1)

# %%
df3.groupby(['custid', 'store']).count()
# Out:
#               date
# custid store
# 0      무역점       5
#        본점        6
# 1      무역점       4
#        본점       22
# 2      무역점       8
# ...            ...
# 49991  신촌점      10
# 49992  본점        2
# 49993  신촌점       4
# 49994  무역점       1
#        본점        2
#
# [83039 rows x 1 columns]

# %%
df
# Out:
#          custid         date_time store        product     brand   corner  \
# 0             0  2000-06-25 12:12   무역점  2116050008000     에스티로더  수입종합화장품
# 1             0  2000-06-25 12:42   무역점  4125440008000       시슬리  수입종합화장품
# 2             0  2000-08-26 18:10    본점  2116052008000      크리니크  수입종합화장품
# 3             0  2000-08-26 18:30    본점  4106430119900        듀퐁     수입의류
# 4             0  2000-09-03 18:02   무역점  2139141008000        랑콤  수입종합화장품
# ...         ...               ...   ...            ...       ...      ...
# 1726425   49993  2001-01-31 17:50   신촌점  4405551020474       톰키드       아동
# 1726426   49993  2001-01-31 18:33   신촌점  2139140008300     폴로화장품       향수
# 1726427   49994  2001-04-14 17:50    본점  4230120011274      스테파넬     영트랜드
# 1726428   49994  2001-04-14 18:10    본점  4409271026010  써스데이아일앤드     진케주얼
# 1726429   49994  2001-04-15 16:02   무역점  2116052008000      크리니크  수입종합화장품
#
#            pc       part  imported  amount  discount  installment
# 0         화장품       명품잡화         1   90000      9000            3
# 1         화장품       명품잡화         1   39000      3900            1
# 2         화장품       잡화파트         1  175000     17500            3
# 3        명품토탈       잡화파트         1  455000     45500            3
# 4         화장품       명품잡화         0  100000     10000            3
# ...       ...        ...       ...     ...       ...          ...
# 1726425    아동       아동문화         0   20000         0            1
# 1726426   화장품       패션잡화         0   70000      3500            1
# 1726427  영트렌디  케주얼,구두,아동         0   39000         0            1
# 1726428  진케주얼  케주얼,구두,아동         0   34200         0            1
# 1726429   화장품       명품잡화         1   86000      8600            1
#
# [1726430 rows x 12 columns]

# %%
df.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-ea942bf769f0> in <module>
# ----> 1 df.columns()
#
# TypeError: 'Index' object is not callable

# %%
df.columns
# Out:
# Index(['custid', 'date_time', 'store', 'product', 'brand', 'corner', 'pc',
#        'part', 'imported', 'amount', 'discount', 'installment'],
#       dtype='object')

# %%
df4 = df[['store', 'corner', 'amount']]

# %%
df4
# Out:
#         store   corner  amount
# 0         무역점  수입종합화장품   90000
# 1         무역점  수입종합화장품   39000
# 2          본점  수입종합화장품  175000
# 3          본점     수입의류  455000
# 4         무역점  수입종합화장품  100000
# ...       ...      ...     ...
# 1726425   신촌점       아동   20000
# 1726426   신촌점       향수   70000
# 1726427    본점     영트랜드   39000
# 1726428    본점     진케주얼   34200
# 1726429   무역점  수입종합화장품   86000
#
# [1726430 rows x 3 columns]

# %%
is_return = df4['amount'] <0
df4 = df4[is_return]
df4
# Out:
#         store   corner   amount
# 18         본점      란제리   -35000
# 21         본점     영트랜드   -73000
# 39        무역점    트래디셔널  -434500
# 46        무역점     가전특정 -1416000
# 60        천호점     영캐쥬얼   -74600
# ...       ...      ...      ...
# 1726286   신촌점       아동  -261000
# 1726287   신촌점  칼라드래디셔널  -308000
# 1726326   신촌점  뉴베이직캐주얼  -200000
# 1726359   무역점      아동복   -98000
# 1726360   무역점      아동복  -205000
#
# [115941 rows x 3 columns]

# %%
df4 = df4.groupby(['corner', 'store']).count().sort_values(by=['amount'], axis=0, ascending=False)

# %%
df4
# Out:
#                amount
# corner  store
# 영트랜드    본점       2974
# 영캐주얼    무역점      2782
# 캐릭터     무역점      2694
# 영캐주얼    신촌점      2665
# 수입종합화장품 본점       2629
# ...               ...
# 오디오     본점          1
# 인스탄트식품  천호점         1
#         신촌점         1
# 피혁      무역점         1
# 인스턴트식품  무역점         1
#
# [509 rows x 1 columns]

# %%
df5 = df['date_time']
df5 = df5.drop_duplicates()
df5 = df5.reset_index(drop=True)
df5
# Out:
# 0        2000-06-25 12:12
# 1        2000-06-25 12:42
# 2        2000-08-26 18:10
# 3        2000-08-26 18:30
# 4        2000-09-03 18:02
#                ...
# 81718    2000-10-31 19:02
# 81719    2001-01-31 18:32
# 81720    2001-02-11 19:42
# 81721    2001-04-08 20:04
# 81722    2000-10-09 16:14
# Name: date_time, Length: 81723, dtype: object

# %%
df
# Out:
#          custid         date_time store        product     brand   corner  \
# 0             0  2000-06-25 12:12   무역점  2116050008000     에스티로더  수입종합화장품
# 1             0  2000-06-25 12:42   무역점  4125440008000       시슬리  수입종합화장품
# 2             0  2000-08-26 18:10    본점  2116052008000      크리니크  수입종합화장품
# 3             0  2000-08-26 18:30    본점  4106430119900        듀퐁     수입의류
# 4             0  2000-09-03 18:02   무역점  2139141008000        랑콤  수입종합화장품
# ...         ...               ...   ...            ...       ...      ...
# 1726425   49993  2001-01-31 17:50   신촌점  4405551020474       톰키드       아동
# 1726426   49993  2001-01-31 18:33   신촌점  2139140008300     폴로화장품       향수
# 1726427   49994  2001-04-14 17:50    본점  4230120011274      스테파넬     영트랜드
# 1726428   49994  2001-04-14 18:10    본점  4409271026010  써스데이아일앤드     진케주얼
# 1726429   49994  2001-04-15 16:02   무역점  2116052008000      크리니크  수입종합화장품
#
#            pc       part  imported  amount  discount  installment
# 0         화장품       명품잡화         1   90000      9000            3
# 1         화장품       명품잡화         1   39000      3900            1
# 2         화장품       잡화파트         1  175000     17500            3
# 3        명품토탈       잡화파트         1  455000     45500            3
# 4         화장품       명품잡화         0  100000     10000            3
# ...       ...        ...       ...     ...       ...          ...
# 1726425    아동       아동문화         0   20000         0            1
# 1726426   화장품       패션잡화         0   70000      3500            1
# 1726427  영트렌디  케주얼,구두,아동         0   39000         0            1
# 1726428  진케주얼  케주얼,구두,아동         0   34200         0            1
# 1726429   화장품       명품잡화         1   86000      8600            1
#
# [1726430 rows x 12 columns]

# %%
df6 = df[['brand', 'amount']]
df6
# Out:
#             brand  amount
# 0           에스티로더   90000
# 1             시슬리   39000
# 2            크리니크  175000
# 3              듀퐁  455000
# 4              랑콤  100000
# ...           ...     ...
# 1726425       톰키드   20000
# 1726426     폴로화장품   70000
# 1726427      스테파넬   39000
# 1726428  써스데이아일앤드   34200
# 1726429      크리니크   86000
#
# [1726430 rows x 2 columns]

# %%
df6.groupby(['brand']).sum().sort_values(['amount'])
# Out:
#              amount
# brand
# 지앤드지        -850000
# M  파죠티      -328000
# 판타지아        -177000
# 난다          -169600
# 스톰          -118300
# ...             ...
# 랑콤       1682242620
# 폴로       1993552300
# 에스티로더    1993933100
# 시슬리      2325004820
# 식품      16004472922
#
# [1906 rows x 1 columns]

# %%
dff = pd.read_csv("weather.csv", encoding = 'cp949')

# %%
dff
# Out:
#        지점 지점명                일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  \
# 0     108  서울  2000-05-01 01:00    11.3         0      NaN        NaN
# 1     108  서울  2000-05-01 02:00    11.3         0      NaN        NaN
# 2     108  서울  2000-05-01 03:00    11.6         0      NaN        NaN
# 3     108  서울  2000-05-01 04:00    11.3         0      NaN        NaN
# 4     108  서울  2000-05-01 05:00    11.5         0      NaN        NaN
# ...   ...  ..               ...     ...       ...      ...        ...
# 8731  108  서울  2001-04-29 20:00    21.4         0      NaN        NaN
# 8732  108  서울  2001-04-29 21:00    20.6         0      NaN        NaN
# 8733  108  서울  2001-04-29 22:00    19.4         0      NaN        NaN
# 8734  108  서울  2001-04-29 23:00    19.0         0      NaN        NaN
# 8735  108  서울  2001-04-30 00:00    18.6         0      NaN        NaN
#
#       풍속(m/s)  풍속 QC플래그  풍향(16방위)  ...  최저운고(100m )  시정(10m)  지면상태(지면상태코드)  \
# 0         2.6         0       200  ...          NaN      NaN           NaN
# 1         1.5         0       200  ...          NaN      NaN           NaN
# 2         1.4         0       110  ...         10.0    300.0           0.0
# 3         0.5         0       110  ...          NaN      NaN           NaN
# 4         2.0         0       110  ...          NaN      NaN           NaN
# ...       ...       ...       ...  ...          ...      ...           ...
# 8731      2.8         0        90  ...          NaN      NaN           NaN
# 8732      3.3         0        70  ...         15.0   1800.0           0.0
# 8733      3.7         0        70  ...          NaN      NaN           NaN
# 8734      3.7         0        70  ...          NaN      NaN           NaN
# 8735      3.7         0        70  ...         12.0   1500.0           NaN
#
#       현상번호(국내식)  지면온도(°C)  지면온도 QC플래그  5cm 지중온도(°C)  10cm 지중온도(°C)  \
# 0          19.0       NaN           9           NaN            NaN
# 1          19.0       NaN           9           NaN            NaN
# 2          19.0      11.4           0          13.7           14.8
# 3          19.0       NaN           9           NaN            NaN
# 4          19.0       NaN           9           NaN            NaN
# ...         ...       ...         ...           ...            ...
# 8731        NaN       NaN           9           NaN            NaN
# 8732        NaN      19.3           0          20.6           20.6
# 8733        NaN       NaN           9           NaN            NaN
# 8734        NaN       NaN           9           NaN            NaN
# 8735        NaN       NaN           9           NaN            NaN
#
#       20cm 지중온도(°C)  30cm 지중온도(°C)
# 0               NaN            NaN
# 1               NaN            NaN
# 2              15.7           15.7
# 3               NaN            NaN
# 4               NaN            NaN
# ...             ...            ...
# 8731            NaN            NaN
# 8732           18.7           16.7
# 8733            NaN            NaN
# 8734            NaN            NaN
# 8735            NaN            NaN
#
# [8736 rows x 37 columns]

# %%
dff = dff[['일시', '기온(°C)', '강수량(mm)' , '습도(%)','적설(cm)',  '일조(hr)']]

# %%
dff.columns
# Out:
# Index(['지점', '지점명', '일시', '기온(°C)', '기온 QC플래그', '강수량(mm)', '강수량 QC플래그',
#        '풍속(m/s)', '풍속 QC플래그', '풍향(16방위)', '풍향 QC플래그', '습도(%)', '습도 QC플래그',
#        '증기압(hPa)', '이슬점온도(°C)', '현지기압(hPa)', '현지기압 QC플래그', '해면기압(hPa)',
#        '해면기압 QC플래그', '일조(hr)', '일조 QC플래그', '일사(MJ/m2)', '적설(cm)', '3시간신적설(cm)',
#        '전운량(10분위)', '중하층운량(10분위)', '운형(운형약어)', '최저운고(100m )', '시정(10m)',
#        '지면상태(지면상태코드)', '현상번호(국내식)', '지면온도(°C)', '지면온도 QC플래그', '5cm 지중온도(°C)',
#        '10cm 지중온도(°C)', '20cm 지중온도(°C)', '30cm 지중온도(°C)'],
#       dtype='object')

# %%
dff
# Out:
#                     일시  기온(°C)  강수량(mm)  습도(%)  적설(cm)  일조(hr)
# 0     2000-05-01 01:00    11.3      NaN     85     NaN     NaN
# 1     2000-05-01 02:00    11.3      NaN     83     NaN     NaN
# 2     2000-05-01 03:00    11.6      NaN     83     NaN     NaN
# 3     2000-05-01 04:00    11.3      NaN     82     NaN     NaN
# 4     2000-05-01 05:00    11.5      NaN     82     NaN     NaN
# ...                ...     ...      ...    ...     ...     ...
# 8731  2001-04-29 20:00    21.4      NaN     42     NaN     0.0
# 8732  2001-04-29 21:00    20.6      NaN     45     NaN     NaN
# 8733  2001-04-29 22:00    19.4      NaN     51     NaN     NaN
# 8734  2001-04-29 23:00    19.0      NaN     56     NaN     NaN
# 8735  2001-04-30 00:00    18.6      NaN     58     NaN     NaN
#
# [8736 rows x 6 columns]

# %%
dff.to_csv('weather1.csv',index=False)

# %%
dff = pd.read_csv('weather1.csv')

# %%
dff
# Out:
#                     일시  기온(°C)  강수량(mm)  습도(%)  적설(cm)  일조(hr)
# 0     2000-05-01 01:00    11.3      NaN     85     NaN     NaN
# 1     2000-05-01 02:00    11.3      NaN     83     NaN     NaN
# 2     2000-05-01 03:00    11.6      NaN     83     NaN     NaN
# 3     2000-05-01 04:00    11.3      NaN     82     NaN     NaN
# 4     2000-05-01 05:00    11.5      NaN     82     NaN     NaN
# ...                ...     ...      ...    ...     ...     ...
# 8731  2001-04-29 20:00    21.4      NaN     42     NaN     0.0
# 8732  2001-04-29 21:00    20.6      NaN     45     NaN     NaN
# 8733  2001-04-29 22:00    19.4      NaN     51     NaN     NaN
# 8734  2001-04-29 23:00    19.0      NaN     56     NaN     NaN
# 8735  2001-04-30 00:00    18.6      NaN     58     NaN     NaN
#
# [8736 rows x 6 columns]

# %%
df = pd.read_csv('X_train.csv', encoding='cp949')
dff = pd.read_csv('y_train.csv', encoding='cp949')
dff
# Out:
#        custid  gender
# 0           0       1
# 1           1       1
# 2           2       1
# 3           3       0
# 4           4       0
# ...       ...     ...
# 29995   29995       1
# 29996   29996       0
# 29997   29997       1
# 29998   29998       0
# 29999   29999       0
#
# [30000 rows x 2 columns]

# %%
df = pd.read_csv('X_train.csv', encoding='cp949')
dff = pd.read_csv('y_train.csv', encoding='cp949')
dff
df = df.merge(dff, how='left', on = 'custid')
df
# Out:
#          custid         date_time store        product  brand   corner  \
# 0             0  2000-06-25 12:12   무역점  2116050008000  에스티로더  수입종합화장품
# 1             0  2000-06-25 12:42   무역점  4125440008000    시슬리  수입종합화장품
# 2             0  2000-08-26 18:10    본점  2116052008000   크리니크  수입종합화장품
# 3             0  2000-08-26 18:30    본점  4106430119900     듀퐁     수입의류
# 4             0  2000-09-03 18:02   무역점  2139141008000     랑콤  수입종합화장품
# ...         ...               ...   ...            ...    ...      ...
# 1036648   29998  2001-01-21 13:20   무역점  4241080013074    바닐라     영캐주얼
# 1036649   29998  2001-04-07 16:33   무역점  2139141008000     랑콤  수입종합화장품
# 1036650   29999  2001-03-21 18:03   천호점  4109290004000  루이까또즈      핸드백
# 1036651   29999  2001-03-29 18:23   천호점  4139350206500  소피에르핀      넥타이
# 1036652   29999  2001-04-21 13:13   천호점  4104840008000     샤넬  수입종합화장품
#
#               pc   part  imported  amount  discount  installment  gender
# 0            화장품   명품잡화         1   90000      9000            3       1
# 1            화장품   명품잡화         1   39000      3900            1       1
# 2            화장품   잡화파트         1  175000     17500            3       1
# 3           명품토탈   잡화파트         1  455000     45500            3       1
# 4            화장품   명품잡화         0  100000     10000            3       1
# ...          ...    ...       ...     ...       ...          ...     ...
# 1036648  트랜디 케쥬얼  여성캐주얼         0  120000         0            3       0
# 1036649      화장품   명품잡화         0   38000      1900            1       0
# 1036650      핸드백     잡화         0   46000      2300            1       0
# 1036651       셔츠   남성의류         0   49000      2450            1       0
# 1036652      화장품     잡화         1   52000      2600            1       0
#
# [1036653 rows x 13 columns]

# %%
dff = pd.DataFrame({'store':['무역점','본점','신촌점', '천호점'], 'store_f': [1,2,3,4]})
dff
# Out:
#   store  store_f
# 0   무역점        1
# 1    본점        2
# 2   신촌점        3
# 3   천호점        4

# %%
df = df.merge(dff, how='left', on = 'store')
df
# Out:
#          custid         date_time store        product  brand   corner  \
# 0             0  2000-06-25 12:12   무역점  2116050008000  에스티로더  수입종합화장품
# 1             0  2000-06-25 12:42   무역점  4125440008000    시슬리  수입종합화장품
# 2             0  2000-08-26 18:10    본점  2116052008000   크리니크  수입종합화장품
# 3             0  2000-08-26 18:30    본점  4106430119900     듀퐁     수입의류
# 4             0  2000-09-03 18:02   무역점  2139141008000     랑콤  수입종합화장품
# ...         ...               ...   ...            ...    ...      ...
# 1036648   29998  2001-01-21 13:20   무역점  4241080013074    바닐라     영캐주얼
# 1036649   29998  2001-04-07 16:33   무역점  2139141008000     랑콤  수입종합화장품
# 1036650   29999  2001-03-21 18:03   천호점  4109290004000  루이까또즈      핸드백
# 1036651   29999  2001-03-29 18:23   천호점  4139350206500  소피에르핀      넥타이
# 1036652   29999  2001-04-21 13:13   천호점  4104840008000     샤넬  수입종합화장품
#
#               pc   part  imported  amount  discount  installment  store_f
# 0            화장품   명품잡화         1   90000      9000            3        1
# 1            화장품   명품잡화         1   39000      3900            1        1
# 2            화장품   잡화파트         1  175000     17500            3        2
# 3           명품토탈   잡화파트         1  455000     45500            3        2
# 4            화장품   명품잡화         0  100000     10000            3        1
# ...          ...    ...       ...     ...       ...          ...      ...
# 1036648  트랜디 케쥬얼  여성캐주얼         0  120000         0            3        1
# 1036649      화장품   명품잡화         0   38000      1900            1        1
# 1036650      핸드백     잡화         0   46000      2300            1        4
# 1036651       셔츠   남성의류         0   49000      2450            1        4
# 1036652      화장품     잡화         1   52000      2600            1        4
#
# [1036653 rows x 13 columns]

# %%
len(df['brand'].drop_duplicates())
# Out:
# 1882

# %%
part_list = df['part'].drop_duplicates()

# %%
part_list = part_list.to_list()

# %%
part_list
# Out:
# ['명품잡화',
#  '잡화파트',
#  '남성의류',
#  '골프/유니캐쥬얼',
#  '로얄부띠끄',
#  '케주얼,구두,아동',
#  '여성캐주얼',
#  '여성의류파트',
#  '가정용품',
#  '가정용품파트',
#  '남성정장스포츠',
#  '아동',
#  '잡화',
#  '영어덜트캐쥬얼',
#  '영라이브',
#  '공산품',
#  '스포츠캐쥬얼',
#  '여성정장',
#  '아동문화',
#  '공산품파트',
#  '생식품파트',
#  '영플라자',
#  '생식품',
#  '패션잡화',
#  '아동,스포츠',
#  '로얄부틱',
#  '여성캐쥬얼',
#  '스포츠캐주얼',
#  '영캐릭터',
#  '상품개발영업1과',
#  '인터넷백화점']

# %%
is_return = df['amount'] > 0
df4 = df[is_return]
df4 = df4[['brand', 'part', 'amount']]
df4
# Out:
#          brand   part  amount
# 0        에스티로더   명품잡화   90000
# 1          시슬리   명품잡화   39000
# 2         크리니크   잡화파트  175000
# 3           듀퐁   잡화파트  455000
# 4           랑콤   명품잡화  100000
# ...        ...    ...     ...
# 1036648    바닐라  여성캐주얼  120000
# 1036649     랑콤   명품잡화   38000
# 1036650  루이까또즈     잡화   46000
# 1036651  소피에르핀   남성의류   49000
# 1036652     샤넬     잡화   52000
#
# [967454 rows x 3 columns]

# %%
df5 = df4.groupby(['part', 'brand']).count().sort_values(by=['amount'], axis=0, ascending=False)
df5
# Out:
#                  amount
# part  brand
# 공산품   식품          94118
# 생식품   식품          63028
# 공산품파트 식품          42817
# 생식품파트 식품          32997
# 잡화파트  샤넬           4439
# ...                 ...
# 명품잡화  진송카르타모피소품       1
#       지오수입의류          1
#       지앤지             1
#       조이너스            1
# 가정용품  캔디시             1
#
# [3652 rows x 1 columns]

# %%
tmp = df5.loc['잡화파트'].head(5)
tmp
# Out:
#            amount
# brand
# 샤넬           4439
# 아베다          3433
# 랑콤           3364
# 에스티로더        2979
# 크리스챤디올화장품    2485

# %%
temp = tmp.index.tolist()
temp
# Out:
# ['샤넬', '아베다', '랑콤', '에스티로더', '크리스챤디올화장품']

# %%
brand_list = []
for i,j in zip(range(len(part_list)),part_list):
    tmp = df5.loc[j].head(5)
    brand_list.append(tmp)
brand_list
# Out:
# [           amount
#  brand
#  랑콤           3643
#  에스티로더        3265
#  크리니크         2832
#  크리스챤디올화장품    2765
#  아베다          2359,
#             amount
#  brand
#  샤넬           4439
#  아베다          3433
#  랑콤           3364
#  에스티로더        2979
#  크리스챤디올화장품    2485,
#           amount
#  brand
#  닥스         1997
#  피에르가르뎅     1908
#  입생로랑(캐)    1357
#  카운테스마라     1237
#  니나리찌       1189,
#           amount
#  brand
#  지오다노       4199
#  폴로         2760
#  빈폴         1223
#  1492마일즈     925
#  퀵실버         887,
#              amount
#  brand
#  버버리            861
#  막스앤스펜서수입의류     767
#  에뜨로            644
#  막스마라           406
#  지아니베르사체        379,
#         amount
#  brand
#  지오다노     4233
#  폴로       3275
#  쇼콜라      1416
#  NUK      1398
#  빈폴       1225,
#            amount
#  brand
#  밀라노스토리무역    1250
#  시스템         1179
#  비너스         1173
#  비비안         1163
#  베네통         1026,
#         amount
#  brand
#  마인       1128
#  타임       1083
#  랄프로렌      756
#  아이잗바바     577
#  오일릴리      558,
#         amount
#  brand
#  필립스      1398
#  삼성        994
#  브라운       796
#  오진/코렐     746
#  홈데코       708,
#         amount
#  brand
#  왕왕상사      592
#  한길통상      582
#  필립스       491
#  브라운       446
#  엘지        433,
#         amount
#  brand
#  엘로드       919
#  아레나       683
#  레노마골프     636
#  닥스        631
#  슈페리어      621,
#           amount
#  brand
#  NUK         922
#  무냐무냐        802
#  빈           693
#  지오다노쥬니어     642
#  블루독         547,
#         amount
#  brand
#  샤넬       2612
#  랑콤       2161
#  아모레      2137
#  에스티로더    2136
#  크리니크     1550,
#                 amount
#  brand
#  베네통               770
#  밀라노스토리  천호점지원     644
#  ABFZ              473
#  마인                419
#  메쎄                379,
#           amount
#  brand
#  지오다노       3639
#  NII        1416
#  시스템         633
#  WWS         633
#  스포트리플레이     571,
#         amount
#  brand
#  식품      94118
#  미등록상품      48,
#         amount
#  brand
#  폴로       1347
#  빈폴       1144
#  라코스떼      721
#  아레나       457
#  컬럼비아      365,
#         amount
#  brand
#  정호진      1076
#  닥스숙녀      910
#  뻬띠앙뜨      767
#  에스깔리에     705
#  모라도       567,
#           amount
#  brand
#  NUK        1250
#  지오다노쥬니어     863
#  쇼콜라         799
#  알파문구        739
#  아가방         672,
#         amount
#  brand
#  식품      42817
#  미등록상품       3,
#         amount
#  brand
#  식품      32997,
#         amount
#  brand
#  지오다노     3962
#  TBJ      1547
#  바디       1315
#  옴파로스     1194
#  SJ        875,
#         amount
#  brand
#  식품      63028
#  미등록상품       3,
#         amount
#  brand
#  랑콤       3411
#  샤넬       3056
#  크리니크     3050
#  에스티로더    2854
#  아모레      2356,
#           amount
#  brand
#  NUK        1205
#  쇼콜라         972
#  폴로보이즈       854
#  블루독         788
#  지오다노쥬니어     775,
#              amount
#  brand
#  막스앤스펜서수입의류     643
#  버버리            299
#  오일릴리           252
#  비앙카수입의류        200
#  박윤수            181,
#         amount
#  brand
#  비너스       576
#  랄프로렌      557
#  비비안       542
#  로제르       404
#  트라이엄프     403,
#         amount
#  brand
#  폴로       1649
#  빈폴       1201
#  나이키의류     498
#  아놀드파마     470
#  컬럼비아      456,
#           amount
#  brand
#  밀라노  신촌     881
#  쿠가이         630
#  타임          601
#  스테파넬        474
#  마인          455,
#         amount
#  brand
#  아르모니아       1,
#         amount
#  brand
#  올젠          1]

# %%
brand_list[0]
# Out:
# ['랑콤', '에스티로더', '크리니크', '크리스챤디올화장품', '아베다']

# %%
for i,j in zip(brand_list, part_list):
    print(i.describe())
    x = i.index.tolist()
    y = i['amount'].tolist()
    for k in range(len(i)):
        plt.bar(x[k], y[k], label=x[k])
    plt.title(j)
    plt.xlabel('브랜드 명')
    plt.ylabel('거래 횟수')
    plt.legend()
    plt.show()
# Out:
#             amount
# count     5.000000
# mean   2972.800000
# std     493.534396
# min    2359.000000
# 25%    2765.000000
# 50%    2832.000000
# 75%    3265.000000
# max    3643.000000
#             amount
# count     5.000000
# mean   3340.000000
# std     720.827996
# min    2485.000000
# 25%    2979.000000
# 50%    3364.000000
# 75%    3433.000000
# max    4439.000000
#             amount
# count     5.000000
# mean   1537.600000
# std     384.949088
# min    1189.000000
# 25%    1237.000000
# 50%    1357.000000
# 75%    1908.000000
# max    1997.000000
#             amount
# count     5.000000
# mean   1998.800000
# std    1450.113513
# min     887.000000
# 25%     925.000000
# 50%    1223.000000
# 75%    2760.000000
# max    4199.000000
#            amount
# count    5.000000
# mean   611.400000
# std    214.343883
# min    379.000000
# 25%    406.000000
# 50%    644.000000
# 75%    767.000000
# max    861.000000
#             amount
# count     5.000000
# mean   2309.400000
# std    1363.575924
# min    1225.000000
# 25%    1398.000000
# 50%    1416.000000
# 75%    3275.000000
# max    4233.000000
#             amount
# count     5.000000
# mean   1158.200000
# std      81.515029
# min    1026.000000
# 25%    1163.000000
# 50%    1173.000000
# 75%    1179.000000
# max    1250.000000
#             amount
# count     5.000000
# mean    820.400000
# std     271.947238
# min     558.000000
# 25%     577.000000
# 50%     756.000000
# 75%    1083.000000
# max    1128.000000
#             amount
# count     5.000000
# mean    928.400000
# std     284.694222
# min     708.000000
# 25%     746.000000
# 50%     796.000000
# 75%     994.000000
# max    1398.000000
#            amount
# count    5.000000
# mean   508.800000
# std     74.643821
# min    433.000000
# 25%    446.000000
# 50%    491.000000
# 75%    582.000000
# max    592.000000
#            amount
# count    5.000000
# mean   698.000000
# std    125.825276
# min    621.000000
# 25%    631.000000
# 50%    636.000000
# 75%    683.000000
# max    919.000000
#            amount
# count    5.000000
# mean   721.200000
# std    145.140277
# min    547.000000
# 25%    642.000000
# 50%    693.000000
# 75%    802.000000
# max    922.000000
#             amount
# count     5.000000
# mean   2119.200000
# std     377.222348
# min    1550.000000
# 25%    2136.000000
# 50%    2137.000000
# 75%    2161.000000
# max    2612.000000
#            amount
# count    5.000000
# mean   537.000000
# std    164.865096
# min    379.000000
# 25%    419.000000
# 50%    473.000000
# 75%    644.000000
# max    770.000000
#             amount
# count     5.000000
# mean   1378.400000
# std    1310.998017
# min     571.000000
# 25%     633.000000
# 50%     633.000000
# 75%    1416.000000
# max    3639.000000
#              amount
# count      2.000000
# mean   47083.000000
# std    66517.534906
# min       48.000000
# 25%    23565.500000
# 50%    47083.000000
# 75%    70600.500000
# max    94118.000000
#             amount
# count     5.000000
# mean    806.800000
# std     427.325637
# min     365.000000
# 25%     457.000000
# 50%     721.000000
# 75%    1144.000000
# max    1347.000000
#             amount
# count     5.000000
# mean    805.000000
# std     195.290809
# min     567.000000
# 25%     705.000000
# 50%     767.000000
# 75%     910.000000
# max    1076.000000
#             amount
# count     5.000000
# mean    864.600000
# std     226.775881
# min     672.000000
# 25%     739.000000
# 50%     799.000000
# 75%     863.000000
# max    1250.000000
#             amount
# count      2.00000
# mean   21410.00000
# std    30274.06973
# min        3.00000
# 25%    10706.50000
# 50%    21410.00000
# 75%    32113.50000
# max    42817.00000
#         amount
# count      1.0
# mean   32997.0
# std        NaN
# min    32997.0
# 25%    32997.0
# 50%    32997.0
# 75%    32997.0
# max    32997.0
#             amount
# count     5.000000
# mean   1778.600000
# std    1244.392342
# min     875.000000
# 25%    1194.000000
# 50%    1315.000000
# 75%    1547.000000
# max    3962.000000
#              amount
# count      2.000000
# mean   31515.500000
# std    44565.404884
# min        3.000000
# 25%    15759.250000
# 50%    31515.500000
# 75%    47271.750000
# max    63028.000000
#             amount
# count     5.000000
# mean   2945.400000
# std     385.909057
# min    2356.000000
# 25%    2854.000000
# 50%    3050.000000
# 75%    3056.000000
# max    3411.000000
#             amount
# count     5.000000
# mean    918.800000
# std     177.993539
# min     775.000000
# 25%     788.000000
# 50%     854.000000
# 75%     972.000000
# max    1205.000000
#            amount
# count    5.000000
# mean   315.000000
# std    189.070093
# min    181.000000
# 25%    200.000000
# 50%    252.000000
# 75%    299.000000
# max    643.000000
#            amount
# count    5.000000
# mean   496.400000
# std     85.658041
# min    403.000000
# 25%    404.000000
# 50%    542.000000
# 75%    557.000000
# max    576.000000
#             amount
# count     5.000000
# mean    854.800000
# std     544.294681
# min     456.000000
# 25%     470.000000
# 50%     498.000000
# 75%    1201.000000
# max    1649.000000
#            amount
# count    5.000000
# mean   608.200000
# std    170.606858
# min    455.000000
# 25%    474.000000
# 50%    601.000000
# 75%    630.000000
# max    881.000000
#        amount
# count     1.0
# mean      1.0
# std       NaN
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
#        amount
# count     1.0
# mean      1.0
# std       NaN
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0

# %%
df_w  = pd.read_csv('weather1.csv')
df_w
# Out:
#                     일시  기온(°C)  강수량(mm)  습도(%)  적설(cm)  일조(hr)
# 0     2000-05-01 01:00    11.3      NaN     85     NaN     NaN
# 1     2000-05-01 02:00    11.3      NaN     83     NaN     NaN
# 2     2000-05-01 03:00    11.6      NaN     83     NaN     NaN
# 3     2000-05-01 04:00    11.3      NaN     82     NaN     NaN
# 4     2000-05-01 05:00    11.5      NaN     82     NaN     NaN
# ...                ...     ...      ...    ...     ...     ...
# 8731  2001-04-29 20:00    21.4      NaN     42     NaN     0.0
# 8732  2001-04-29 21:00    20.6      NaN     45     NaN     NaN
# 8733  2001-04-29 22:00    19.4      NaN     51     NaN     NaN
# 8734  2001-04-29 23:00    19.0      NaN     56     NaN     NaN
# 8735  2001-04-30 00:00    18.6      NaN     58     NaN     NaN
#
# [8736 rows x 6 columns]

# %%
import datetime as dt

# %%
s = dt.datetime(2018, 10, 9, 10)
print(s)
# Out:
# 2018-10-09 10:00:00

# %%
df = pd.read_csv("X_train.csv", encoding = 'cp949')

# %%
df3 = df
data = []
for i, j in zip(df3['date_time'], range(len(df3))):
    tmp = i[:14]+'00'
    data.append(tmp)
data = pd.Series(data)
df3['일시'] = data
df3 = df3.drop(['date_time'], axis=1)
df3
# Out:
#          custid store        product  brand   corner       pc   part  \
# 0             0   무역점  2116050008000  에스티로더  수입종합화장품      화장품   명품잡화
# 1             0   무역점  4125440008000    시슬리  수입종합화장품      화장품   명품잡화
# 2             0    본점  2116052008000   크리니크  수입종합화장품      화장품   잡화파트
# 3             0    본점  4106430119900     듀퐁     수입의류     명품토탈   잡화파트
# 4             0   무역점  2139141008000     랑콤  수입종합화장품      화장품   명품잡화
# ...         ...   ...            ...    ...      ...      ...    ...
# 1036648   29998   무역점  4241080013074    바닐라     영캐주얼  트랜디 케쥬얼  여성캐주얼
# 1036649   29998   무역점  2139141008000     랑콤  수입종합화장품      화장품   명품잡화
# 1036650   29999   천호점  4109290004000  루이까또즈      핸드백      핸드백     잡화
# 1036651   29999   천호점  4139350206500  소피에르핀      넥타이       셔츠   남성의류
# 1036652   29999   천호점  4104840008000     샤넬  수입종합화장품      화장품     잡화
#
#          imported  amount  discount  installment                일시
# 0               1   90000      9000            3  2000-06-25 12:00
# 1               1   39000      3900            1  2000-06-25 12:00
# 2               1  175000     17500            3  2000-08-26 18:00
# 3               1  455000     45500            3  2000-08-26 18:00
# 4               0  100000     10000            3  2000-09-03 18:00
# ...           ...     ...       ...          ...               ...
# 1036648         0  120000         0            3  2001-01-21 13:00
# 1036649         0   38000      1900            1  2001-04-07 16:00
# 1036650         0   46000      2300            1  2001-03-21 18:00
# 1036651         0   49000      2450            1  2001-03-29 18:00
# 1036652         1   52000      2600            1  2001-04-21 13:00
#
# [1036653 rows x 12 columns]

# %%
df = df.merge(df_w, how='left', on = '일시')
df
# Out:
#          custid         date_time store        product  brand   corner  \
# 0             0  2000-06-25 12:12   무역점  2116050008000  에스티로더  수입종합화장품
# 1             0  2000-06-25 12:42   무역점  4125440008000    시슬리  수입종합화장품
# 2             0  2000-08-26 18:10    본점  2116052008000   크리니크  수입종합화장품
# 3             0  2000-08-26 18:30    본점  4106430119900     듀퐁     수입의류
# 4             0  2000-09-03 18:02   무역점  2139141008000     랑콤  수입종합화장품
# ...         ...               ...   ...            ...    ...      ...
# 1036648   29998  2001-01-21 13:20   무역점  4241080013074    바닐라     영캐주얼
# 1036649   29998  2001-04-07 16:33   무역점  2139141008000     랑콤  수입종합화장품
# 1036650   29999  2001-03-21 18:03   천호점  4109290004000  루이까또즈      핸드백
# 1036651   29999  2001-03-29 18:23   천호점  4139350206500  소피에르핀      넥타이
# 1036652   29999  2001-04-21 13:13   천호점  4104840008000     샤넬  수입종합화장품
#
#               pc   part  imported  amount  discount  installment  \
# 0            화장품   명품잡화         1   90000      9000            3
# 1            화장품   명품잡화         1   39000      3900            1
# 2            화장품   잡화파트         1  175000     17500            3
# 3           명품토탈   잡화파트         1  455000     45500            3
# 4            화장품   명품잡화         0  100000     10000            3
# ...          ...    ...       ...     ...       ...          ...
# 1036648  트랜디 케쥬얼  여성캐주얼         0  120000         0            3
# 1036649      화장품   명품잡화         0   38000      1900            1
# 1036650      핸드백     잡화         0   46000      2300            1
# 1036651       셔츠   남성의류         0   49000      2450            1
# 1036652      화장품     잡화         1   52000      2600            1
#
#                        일시  기온(°C)  강수량(mm)  습도(%)  적설(cm)  일조(hr)
# 0        2000-06-25 12:00    27.4      NaN     61     NaN     0.0
# 1        2000-06-25 12:00    27.4      NaN     61     NaN     0.0
# 2        2000-08-26 18:00    22.2      6.5     97     NaN     0.0
# 3        2000-08-26 18:00    22.2      6.5     97     NaN     0.0
# 4        2000-09-03 18:00    23.6      0.8     87     NaN     0.0
# ...                   ...     ...      ...    ...     ...     ...
# 1036648  2001-01-21 13:00     0.2      NaN     61     NaN     0.0
# 1036649  2001-04-07 16:00    16.1      NaN     67     NaN     0.0
# 1036650  2001-03-21 18:00    16.5      NaN     19     NaN     0.2
# 1036651  2001-03-29 18:00     5.0      0.0     52     NaN     0.0
# 1036652  2001-04-21 13:00    17.2      NaN     43     NaN     1.0
#
# [1036653 rows x 18 columns]

# %%
df = pd.read_csv("C:\\Users\\ASIAE_24\\Documents\\data\\X_train.csv", encoding='cp949')
df
# Out:
#          custid         date_time store        product  brand   corner  \
# 0             0  2000-06-25 12:12   무역점  2116050008000  에스티로더  수입종합화장품
# 1             0  2000-06-25 12:42   무역점  4125440008000    시슬리  수입종합화장품
# 2             0  2000-08-26 18:10    본점  2116052008000   크리니크  수입종합화장품
# 3             0  2000-08-26 18:30    본점  4106430119900     듀퐁     수입의류
# 4             0  2000-09-03 18:02   무역점  2139141008000     랑콤  수입종합화장품
# ...         ...               ...   ...            ...    ...      ...
# 1036648   29998  2001-01-21 13:20   무역점  4241080013074    바닐라     영캐주얼
# 1036649   29998  2001-04-07 16:33   무역점  2139141008000     랑콤  수입종합화장품
# 1036650   29999  2001-03-21 18:03   천호점  4109290004000  루이까또즈      핸드백
# 1036651   29999  2001-03-29 18:23   천호점  4139350206500  소피에르핀      넥타이
# 1036652   29999  2001-04-21 13:13   천호점  4104840008000     샤넬  수입종합화장품
#
#               pc   part  imported  amount  discount  installment
# 0            화장품   명품잡화         1   90000      9000            3
# 1            화장품   명품잡화         1   39000      3900            1
# 2            화장품   잡화파트         1  175000     17500            3
# 3           명품토탈   잡화파트         1  455000     45500            3
# 4            화장품   명품잡화         0  100000     10000            3
# ...          ...    ...       ...     ...       ...          ...
# 1036648  트랜디 케쥬얼  여성캐주얼         0  120000         0            3
# 1036649      화장품   명품잡화         0   38000      1900            1
# 1036650      핸드백     잡화         0   46000      2300            1
# 1036651       셔츠   남성의류         0   49000      2450            1
# 1036652      화장품     잡화         1   52000      2600            1
#
# [1036653 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['custid', 'date_time', 'store', 'product', 'brand', 'corner', 'pc',
#        'part', 'imported', 'amount', 'discount', 'installment'],
#       dtype='object')
