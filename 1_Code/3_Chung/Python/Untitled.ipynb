# %%
import pandas as pd

# %%
#R에서 로딩이 안될시 사용

# %%
df = pd.read_csv("./CUST_ORDER_OUTPUT2.utf8.csv", encoding = 'utf-8')
# Out:
# c:\users\asiae_06\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#       LGROUP  MGROUP  SGROUP  DGROUP LGROUP_NAME MGROUP_NAME   SGROUP_NAME  \
# 0         70       2       1       2          식품   신선식품/가공식품       간편/즉석식품
# 1         70       2       1       3          식품   신선식품/가공식품       간편/즉석식품
# 2         70       2       1       4          식품   신선식품/가공식품       간편/즉석식품
# 3         70       2       1       5          식품   신선식품/가공식품       간편/즉석식품
# 4         70       2       1       6          식품   신선식품/가공식품       간편/즉석식품
# ...      ...     ...     ...     ...         ...         ...           ...
# 2314      10       1      10       2       패션/잡화    남성/캐주얼의류     트레이닝/이지웨어
# 2315      10       1      10       3       패션/잡화    남성/캐주얼의류     트레이닝/이지웨어
# 2316      10       1      10       4       패션/잡화    남성/캐주얼의류     트레이닝/이지웨어
# 2317      10       2       1       1       패션/잡화    여성/캐주얼의류     가죽/모피/무스탕
# 2318      40       1      16       7          주방     주방용품/식기  후라이팬/양면팬/구이팬
#
#      DGROUP_NAME  LMSD_CODE
# 0     기타 간편/즉석식품   70020102
# ...

# %%
df.to_csv('CUST_ORDER_OUTPUT2.utf8.csv', encoding = 'cp949')

# %%
df =pd.read_csv('./VHD_GOODSKIND.csv', encoding = 'utf-8')

# %%
df.to_csv('VHD_GOODSKIND.csv', encoding = 'cp949')
